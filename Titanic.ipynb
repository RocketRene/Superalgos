# %%
import seaborn as sns
df = sns.load_dataset('titanic')

# %%
df['fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: fare, Length: 891, dtype: float64

# %%
df[['fare','age']]
# Out:
#         fare   age
# 0     7.2500  22.0
# 1    71.2833  38.0
# 2     7.9250  26.0
# 3    53.1000  35.0
# 4     8.0500  35.0
# ..       ...   ...
# 886  13.0000  27.0
# 887  30.0000  19.0
# 888  23.4500   NaN
# 889  30.0000  26.0
# 890   7.7500  32.0
#
# [891 rows x 2 columns]

# %%
df.iloc[3]
# Out:
# survived                 1
# pclass                   1
# sex                 female
# age                     35
# sibsp                    1
# parch                    0
# fare                  53.1
# embarked                 S
# class                First
# who                  woman
# adult_male           False
# deck                     C
# embark_town    Southampton
# alive                  yes
# alone                False
# Name: 3, dtype: object

# %%
df.iloc[[3,5,8]][['fare','age']]
# Out:
#       fare   age
# 3  53.1000  35.0
# 5   8.4583   NaN
# 8  11.1333  27.0

# %%
df.iloc[[0,1,2],[0,1,2]]
# Out:
#    survived  pclass     sex
# 0         0       3    male
# 1         1       1  female
# 2         1       3  female

# %%
df.iloc[10:31:2][['survived','pclass','sex']]
# Out:
#     survived  pclass     sex
# 10         1       3  female
# 12         0       3    male
# 14         0       3  female
# 16         0       3    male
# 18         0       3  female
# 20         0       2    male
# 22         1       3  female
# 24         0       3  female
# 26         0       3    male
# 28         1       3  female
# 30         0       1    male

# %%
df['survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: survived, Length: 891, dtype: int64

# %%
df[df.pclass ==2]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 15          1       2  female  55.0      0      0  16.0000        S  Second
# 17          1       2    male   NaN      0      0  13.0000        S  Second
# 20          0       2    male  35.0      0      0  26.0000        S  Second
# 21          1       2    male  34.0      0      0  13.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 866         1       2  female  27.0      1      0  13.8583        C  Second
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 886         0       2    male  27.0      0      0  13.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df[df.age<=1]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 78          1       2    male  0.83      0      2   29.0000        S  Second
# 164         0       3    male  1.00      4      1   39.6875        S   Third
# 172         1       3  female  1.00      1      1   11.1333        S   Third
# 183         1       2    male  1.00      2      1   39.0000        S  Second
# 305         1       1    male  0.92      1      2  151.5500        S   First
# 381         1       3  female  1.00      0      2   15.7417        C   Third
# 386         0       3    male  1.00      5      2   46.9000        S   Third
# 469         1       3  female  0.75      2      1   19.2583        C   Third
# 644         1       3  female  0.75      2      1   19.2583        C   Third
# 755         1       2    male  0.67      1      1   14.5000        S  Second
# 788         1       3    male  1.00      1      2   20.5750        S   Third
# ...

# %%
df[df['age'].between(10,13)]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 59          0       3    male  11.0      5      2   46.9000        S   Third
# 125         1       3    male  12.0      1      0   11.2417        C   Third
# 419         0       3  female  10.0      0      2   24.1500        S   Third
# 446         1       2  female  13.0      0      1   19.5000        S  Second
# 542         0       3  female  11.0      4      2   31.2750        S   Third
# 731         0       3    male  11.0      0      0   18.7875        C   Third
# 780         1       3  female  13.0      0      0    7.2292        C   Third
# 802         1       1    male  11.0      1      2  120.0000        S   First
# 819         0       3    male  10.0      3      2   27.9000        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 59   child       False  NaN  Southampton    no  False
# 125  child       False  NaN    Cherbourg   yes  False
# ...

# %%
df[(df.pclass==2)&(df.survived==1)]
# Out:
#      survived  pclass     sex    age  sibsp  parch     fare embarked   class  \
# 9           1       2  female  14.00      1      0  30.0708        C  Second
# 15          1       2  female  55.00      0      0  16.0000        S  Second
# 17          1       2    male    NaN      0      0  13.0000        S  Second
# 21          1       2    male  34.00      0      0  13.0000        S  Second
# 43          1       2  female   3.00      1      2  41.5792        C  Second
# ..        ...     ...     ...    ...    ...    ...      ...      ...     ...
# 831         1       2    male   0.83      1      1  18.7500        S  Second
# 865         1       2  female  42.00      0      0  13.0000        S  Second
# 866         1       2  female  27.00      1      0  13.8583        C  Second
# 874         1       2  female  28.00      1      0  24.0000        C  Second
# 880         1       2  female  25.00      0      1  26.0000        S  Second
#
# ...

# %%
df[df['age'].between(40,50)&(df.embark_town=='Cherbourg')&(df.sex=='female')]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 52          1       1  female  49.0      1      0   76.7292        C  First
# 177         0       1  female  50.0      0      0   28.7125        C  First
# 194         1       1  female  44.0      0      0   27.7208        C  First
# 299         1       1  female  50.0      0      1  247.5208        C  First
# 319         1       1  female  40.0      1      1  134.5000        C  First
# 337         1       1  female  41.0      0      0  134.5000        C  First
# 362         0       3  female  45.0      0      1   14.4542        C  Third
# 380         1       1  female  42.0      0      0  227.5250        C  First
# 523         1       1  female  44.0      0      1   57.9792        C  First
# 556         1       1  female  48.0      1      0   39.6000        C  First
#
#        who  adult_male deck embark_town alive  alone
# 52   woman       False    D   Cherbourg   yes  False
# ...

# %%
df[df.age.notnull()]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.countplot(x='pclass',data=df)

# %%
sns.histplot(df["age"],bins=20)

# %%
sns.boxplot(df['age'])
# Out:
# /Users/renekuhn/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.scatterplot("fare",'age',data=df,hue="pclass")
# Out:
# /Users/renekuhn/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(data=df, x='survived',hue='sex')

# %%
sns.heatmap(df.corr())

# %%
df['pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: pclass, dtype: int64

# %%
df['fare'].sum()
# Out:
# 28693.9493

# %%
df['age'].mean()
# Out:
# 29.69911764705882

# %%
df['age'].median()
# Out:
# 28.0

# %%
df['age'].std()
# Out:
# 14.526497332334044

# %%
df['age'].notnull().count()
# Out:
# 891

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
